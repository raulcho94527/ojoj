# %% [markdown]
# <a href="https://colab.research.google.com/github/Oramgee/-oramge-.github.io/blob/gh-pages/%ED%8C%8C%ED%94%84%EB%A6%AC%EC%B9%B4%ED%9A%8C%EC%83%89%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.image as img
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.colors as colors
from google.colab import files
import cv2
import matplotlib.pyplot as plt
uploaded = files.upload()
# Out:
#      <input type="file" id="files-90e6145c-06a2-49a3-b162-21b570b8d805" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90e6145c-06a2-49a3-b162-21b570b8d805">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.jpeg to test (1).jpeg

# %%
from IPython.display import Image
Image('test.jpeg')

# %%
import matplotlib.pyplot as plt
import cv2

#컬러 영상 출력
imgBGR = cv2.imread('test.jpeg')

# cv2.imread는 BGR로 불러오므로 plt를 이용하려면 RGB로 바꿔줘야 함
imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)

plt.axis('off') # 창에있는 x축 y축 제거
plt.imshow(imgRGB)
plt.show()

# %%
imgGray = cv2.imread('test.jpeg', cv2.IMREAD_GRAYSCALE)

plt.axis('off')
plt.imshow(imgGray, cmap='gray') # cmap='gray'를 입력해주어야함
plt.show()

# %%
import cv2

im = cv2.imread('test.jpeg')
print(type(im))
print(im.shape)
print(type(im.shape))
# Out:
# <class 'numpy.ndarray'>
# (510, 512, 3)
# <class 'tuple'>

# %%
h, w, c = im.shape
print('width:  ', w)
print('height: ', h)
print('channel:', c)
# Out:
# width:   512
# height:  510
# channel: 3
